# %%
import pandas as pd

# Load Excel file as DataFrame with first row as header
df = pd.read_excel('R:\LLM + RAG\Food Composition Tables\Nutrition_Data.xlsx', header=0)

# Round all numeric columns to 1 decimal place
df = df.round(1)

df.head(30)

# %%
df.info()
